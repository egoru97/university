# %% [markdown]
# <a href="https://colab.research.google.com/github/egoru97/university/blob/main/Tasks/first_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
print("1")
print("2")
# Out:
# hello world
